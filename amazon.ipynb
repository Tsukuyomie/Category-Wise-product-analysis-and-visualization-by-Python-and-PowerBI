# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\Amit\Desktop\project for portfolio\AMAZON\amazon.csv')

# %%
data.head(1)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
#
# ...

# %%
data = data.drop(columns= ['user_id','user_name','img_link','review_id'])

# %%
data.head(1)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...

# %%
data['category'] = data['category'].str.replace('|', ' ')
data.head(1)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
#
#                                             category discounted_price  \
# 0  Computers&Accessories Accessories&Peripherals ...             ₹399
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...

# %%
data['Category'] = data['category'].str.split().str[0]

# %%
data['Product'] = data['category'].str.split().str[3]

# %%
data.head(1)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
#
#                                             category discounted_price  \
# 0  Computers&Accessories Accessories&Peripherals ...             ₹399
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
#
#                                         product_link               Category  \
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...  Computers&Accessories
#
#   Product
# 0  Cables

# %%
data['Brand'] = data['product_name'].str.split().str[0]

# %%
data.head(1)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
#
#                                             category discounted_price  \
# 0  Computers&Accessories Accessories&Peripherals ...             ₹399
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
#
#                                         product_link               Category  \
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...  Computers&Accessories
#
#   Product   Brand
# 0  Cables  Wayona

# %%
data = data.drop(columns='category')

# %%
data.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#   discounted_price actual_price discount_percentage rating rating_count  \
# 0             ₹399       ₹1,099                 64%    4.2       24,269
# 1             ₹199         ₹349                 43%    4.0       43,994
# 2             ₹199       ₹1,899                 90%    3.9        7,928
# 3             ₹329         ₹699                 53%    4.2       94,363
# 4             ₹154         ₹399                 61%    4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12,8)

# %%
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.to_excel('Amazon.xlsx')

# %%
data.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#   discounted_price actual_price discount_percentage rating rating_count  \
# 0             ₹399       ₹1,099                 64%    4.2       24,269
# 1             ₹199         ₹349                 43%    4.0       43,994
# 2             ₹199       ₹1,899                 90%    3.9        7,928
# 3             ₹329         ₹699                 53%    4.2       94,363
# 4             ₹154         ₹399                 61%    4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# ...
